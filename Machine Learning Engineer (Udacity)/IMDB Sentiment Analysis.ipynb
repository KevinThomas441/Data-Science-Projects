# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2020-04-14 04:14:26--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  22.5MB/s    in 5.1s
#
# 2020-04-14 04:14:31 (15.7 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'The most bizarre of the cinematic sub-genres is the so called "The Great Ladies of the Grand Guignol": camp horror films which combined over-the-top melodrama with gothic thrills and always starred by seasoned and almost forgotten actress from hollywood golden age in unflattering roles of either long suffering victims or screeching evil harpies. This genre provided them with an unusual acting showcase that allowed strut their stuff on the screen once again and win new generations of fans at expense of their glamorous images from yesterday.<br /><br />"What\'s the matter with Helen" is the last drop of this sub-genre with stunning performances of both Debbie Reynolds and Shelley Winters as the troubled mothers of two convicted criminals who run away from their past to the sunny California in the 1930s to open a talent school to milk out the eagerly mothers who want their daughters to be the next Shirley Temple. In California, Debbie gets happiness, clients, tango, tap dancing and a new love interest (Dennis Weaver meanwhile Shelley gets wacko with horrible flashbacks, menacing anonymous calls, menacing strangers, menacing Agnes Moorehead as a radio evangelist, cute little rabbits (!) and an unfortunate encounter with an electric fan (ouch!).<br /><br />The sloppy script (penned by Henry Farrell, the man who started all this genre with "Whatever Happened to Baby Jane" along with master director Robert Aldrich, Joan Crawford and Bette Davis) is full of plot holes, red herrings and wasted opportunities that could had made this movie great: the underlying themes of twisted motherhood (with Debbie and Shelley\'s characters as "failed mothers" and the overbearing mommies of the child stars) and obsessive female bonding (Debbie and Shelley relationship and the fact that the few male characters of this movie are either sinister or sleazy even Dennis Weaver dream boat Texan) are wasted. Instead we get Debbie Reynolds musicals interludes and dancing tots, although fun to watch take too much screen time of what is supposedly to be a psychological chiller. But still this movie is highly entertaining. The two stars and Curtis Harrington stylish direction easily overcomes its flaws. The movie recreation of the 1930\'s is colorful and elegant (look at Debbie\'s clothes!) made with a very tight budget. The increasing atmosphere of madness and hysteria is genuinely creepy with a shocking finale that will haunt you for days. And you wouldn\'t easily forget that silly "Goody, goody" song that runs through the movie either. And seeing an increasingly mad Shelley Winters screw every one of Debbie Reynolds\' chances at happiness is a hoot to watch!<br /><br />8 out of 10.'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. Make sure that
#       val_X and val_y contain 10 000 entires while train_X and train_y contain the remaining 15 000 entries.
val_X = pd.DataFrame(train_X[:10000])
val_y = pd.DataFrame(train_y[:10000])
train_X = pd.DataFrame(train_X[10000:])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
#       Make sure that the files you create are in the correct format.
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container,
                                   role,
                                   train_instance_count=1,
                                   train_instance_type="ml.m4.xlarge",
                                   output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                   sagemaker_session=session)


# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-04-14 04:24:34 Starting - Starting the training job...
# 2020-04-14 04:24:35 Starting - Launching requested ML instances...
# 2020-04-14 04:25:33 Starting - Preparing the instances for training.........
# 2020-04-14 04:26:39 Downloading - Downloading input data...
# 2020-04-14 04:27:33 Training - Training image download completed. Training in progress..Arguments: train
# [2020-04-14:04:27:33:INFO] Running standalone xgboost training.
# [2020-04-14:04:27:33:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8483.89mb
# [2020-04-14:04:27:33:INFO] Determined delimiter of CSV input is ','
# [04:27:33] S3DistributionType set as FullyReplicated
# [04:27:35] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-04-14:04:27:35:INFO] Determined delimiter of CSV input is ','
# [04:27:35] S3DistributionType set as FullyReplicated
# [04:27:36] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [04:27:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=5
# [0]#011train-error:0.295733#011validation-error:0.3112
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
#
# Will train until validation-error hasn't improved in 10 rounds.
# [04:27:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 12 pruned nodes, max_depth=5
# [1]#011train-error:0.281#011validation-error:0.2919
# [04:27:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=5
# [2]#011train-error:0.2802#011validation-error:0.2888
# [04:27:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [3]#011train-error:0.271333#011validation-error:0.2841
# [04:27:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [4]#011train-error:0.264133#011validation-error:0.2756
# [04:27:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [5]#011train-error:0.254#011validation-error:0.2681
# [04:27:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.2494#011validation-error:0.264
# [04:27:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=5
# [7]#011train-error:0.239733#011validation-error:0.2544
# [04:27:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [8]#011train-error:0.237667#011validation-error:0.2558
# [04:27:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=5
# [9]#011train-error:0.2318#011validation-error:0.2486
# [04:27:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=5
# [10]#011train-error:0.223733#011validation-error:0.2416
# [04:27:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [11]#011train-error:0.217#011validation-error:0.2359
# [04:27:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [12]#011train-error:0.211067#011validation-error:0.2341
# [04:27:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [13]#011train-error:0.2064#011validation-error:0.2299
# [04:27:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [14]#011train-error:0.2032#011validation-error:0.2253
# [04:27:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [15]#011train-error:0.199667#011validation-error:0.2206
# [04:28:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [16]#011train-error:0.197067#011validation-error:0.2185
# [04:28:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=5
# [17]#011train-error:0.194867#011validation-error:0.2159
# [04:28:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [18]#011train-error:0.1922#011validation-error:0.2142
# [04:28:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [19]#011train-error:0.189133#011validation-error:0.2114
# [04:28:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [20]#011train-error:0.186867#011validation-error:0.2084
# [04:28:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [21]#011train-error:0.182933#011validation-error:0.205
# [04:28:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [22]#011train-error:0.178733#011validation-error:0.2032
# [04:28:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [23]#011train-error:0.176067#011validation-error:0.2006
# [04:28:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [24]#011train-error:0.174533#011validation-error:0.1983
# [04:28:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [25]#011train-error:0.172333#011validation-error:0.1975
# [04:28:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [26]#011train-error:0.169333#011validation-error:0.1958
# [04:28:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [27]#011train-error:0.167267#011validation-error:0.1936
# [04:28:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [28]#011train-error:0.166733#011validation-error:0.1933
# [04:28:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [29]#011train-error:0.1642#011validation-error:0.1918
# [04:28:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [30]#011train-error:0.1628#011validation-error:0.1924
# [04:28:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [31]#011train-error:0.1614#011validation-error:0.1899
# [04:28:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [32]#011train-error:0.1596#011validation-error:0.1894
# [04:28:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [33]#011train-error:0.157467#011validation-error:0.1875
# [04:28:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [34]#011train-error:0.156533#011validation-error:0.187
# [04:28:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [35]#011train-error:0.155533#011validation-error:0.1862
# [04:28:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [36]#011train-error:0.155467#011validation-error:0.1845
# [04:28:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=5
# [37]#011train-error:0.1542#011validation-error:0.1844
# [04:28:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [38]#011train-error:0.152533#011validation-error:0.184
# [04:28:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-error:0.1524#011validation-error:0.1833
# [04:28:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [40]#011train-error:0.150467#011validation-error:0.1819
# [04:28:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [41]#011train-error:0.148067#011validation-error:0.1809
# [04:28:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [42]#011train-error:0.146667#011validation-error:0.1797
# [04:28:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [43]#011train-error:0.145#011validation-error:0.1783
# [04:28:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [44]#011train-error:0.143667#011validation-error:0.177
# [04:28:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [45]#011train-error:0.141#011validation-error:0.1764
# [04:28:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [46]#011train-error:0.140867#011validation-error:0.1754
# [04:28:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [47]#011train-error:0.1392#011validation-error:0.1732
# [04:28:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [48]#011train-error:0.139#011validation-error:0.1733
# [04:28:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 18 pruned nodes, max_depth=5
# [49]#011train-error:0.137867#011validation-error:0.1721
# [04:28:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [50]#011train-error:0.136133#011validation-error:0.1716
# [04:28:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [51]#011train-error:0.135533#011validation-error:0.1706
# [04:28:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [52]#011train-error:0.135067#011validation-error:0.17
# [04:28:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [53]#011train-error:0.133467#011validation-error:0.1695
# [04:28:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [54]#011train-error:0.133067#011validation-error:0.1696
# [04:28:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [55]#011train-error:0.132867#011validation-error:0.1701
# [04:28:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [56]#011train-error:0.132467#011validation-error:0.1689
# [04:28:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [57]#011train-error:0.132#011validation-error:0.1682
# [04:28:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [58]#011train-error:0.1314#011validation-error:0.1677
# [04:28:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [59]#011train-error:0.129533#011validation-error:0.1674
# [04:28:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [60]#011train-error:0.1296#011validation-error:0.1675
# [04:28:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [61]#011train-error:0.129067#011validation-error:0.167
# [04:28:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [62]#011train-error:0.128867#011validation-error:0.1674
# [04:29:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [63]#011train-error:0.128333#011validation-error:0.1664
# [04:29:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [64]#011train-error:0.1278#011validation-error:0.1656
# [04:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [65]#011train-error:0.126933#011validation-error:0.1649
# [04:29:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [66]#011train-error:0.126667#011validation-error:0.1647
# [04:29:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [67]#011train-error:0.125533#011validation-error:0.1649
# [04:29:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [68]#011train-error:0.124667#011validation-error:0.1648
# [04:29:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [69]#011train-error:0.1242#011validation-error:0.1637
# [04:29:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [70]#011train-error:0.122867#011validation-error:0.1638
# [04:29:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [71]#011train-error:0.123067#011validation-error:0.1628
# [04:29:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [72]#011train-error:0.121133#011validation-error:0.1623
# [04:29:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [73]#011train-error:0.1208#011validation-error:0.1619
# [04:29:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [74]#011train-error:0.120267#011validation-error:0.1611
# [04:29:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [75]#011train-error:0.118533#011validation-error:0.1616
# [04:29:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [76]#011train-error:0.118933#011validation-error:0.1611
# [04:29:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [77]#011train-error:0.117933#011validation-error:0.1601
# [04:29:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [78]#011train-error:0.117667#011validation-error:0.1588
# [04:29:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [79]#011train-error:0.116733#011validation-error:0.1584
# [04:29:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [80]#011train-error:0.115733#011validation-error:0.1587
# [04:29:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [81]#011train-error:0.114667#011validation-error:0.1578
# [04:29:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [82]#011train-error:0.1132#011validation-error:0.1582
# [04:29:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [83]#011train-error:0.112867#011validation-error:0.1569
# [04:29:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [84]#011train-error:0.1126#011validation-error:0.1557
# [04:29:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [85]#011train-error:0.1118#011validation-error:0.1565
# [04:29:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [86]#011train-error:0.111467#011validation-error:0.1581
# [04:29:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [87]#011train-error:0.111533#011validation-error:0.1574
# [04:29:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [88]#011train-error:0.111867#011validation-error:0.158
# [04:29:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [89]#011train-error:0.112467#011validation-error:0.1578
# [04:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [90]#011train-error:0.111333#011validation-error:0.157
# [04:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [91]#011train-error:0.110933#011validation-error:0.156
# [04:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [92]#011train-error:0.110667#011validation-error:0.1556
# [04:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [93]#011train-error:0.110267#011validation-error:0.1554
# [04:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [94]#011train-error:0.108933#011validation-error:0.155
# [04:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [95]#011train-error:0.109133#011validation-error:0.1544
# [04:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [96]#011train-error:0.108267#011validation-error:0.1541
# [04:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [97]#011train-error:0.1074#011validation-error:0.1542
# [04:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [98]#011train-error:0.107133#011validation-error:0.1536
# [04:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=5
# [99]#011train-error:0.1062#011validation-error:0.1528
# [04:29:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [100]#011train-error:0.1058#011validation-error:0.1532
# [04:29:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [101]#011train-error:0.105067#011validation-error:0.1539
# [04:29:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [102]#011train-error:0.104733#011validation-error:0.1521
# [04:29:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [103]#011train-error:0.1042#011validation-error:0.1518
# [04:29:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [104]#011train-error:0.1042#011validation-error:0.152
# [04:29:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [105]#011train-error:0.1044#011validation-error:0.1521
# [04:29:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [106]#011train-error:0.104133#011validation-error:0.1518
# [04:29:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [107]#011train-error:0.1022#011validation-error:0.1508
# [04:29:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [108]#011train-error:0.101533#011validation-error:0.1516
# [04:29:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [109]#011train-error:0.101467#011validation-error:0.1508
# [04:29:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [110]#011train-error:0.1006#011validation-error:0.1507
# [04:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [111]#011train-error:0.100667#011validation-error:0.1503
# [04:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [112]#011train-error:0.100533#011validation-error:0.1503
# [04:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [113]#011train-error:0.100333#011validation-error:0.1505
# [04:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [114]#011train-error:0.099733#011validation-error:0.1498
# [04:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [115]#011train-error:0.099733#011validation-error:0.1497
# [04:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [116]#011train-error:0.0992#011validation-error:0.1494
# [04:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [117]#011train-error:0.0988#011validation-error:0.1492
# [04:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [118]#011train-error:0.098467#011validation-error:0.1503
# [04:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [119]#011train-error:0.097667#011validation-error:0.1492
# [04:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [120]#011train-error:0.097467#011validation-error:0.1481
# [04:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [121]#011train-error:0.0974#011validation-error:0.1479
# [04:30:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [122]#011train-error:0.096267#011validation-error:0.1478
# [04:30:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [123]#011train-error:0.096267#011validation-error:0.1462
# [04:30:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [124]#011train-error:0.0954#011validation-error:0.1467
# [04:30:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [125]#011train-error:0.0954#011validation-error:0.1463
# [04:30:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [126]#011train-error:0.094867#011validation-error:0.1459
# [04:30:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [127]#011train-error:0.094133#011validation-error:0.1466
# [04:30:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [128]#011train-error:0.0938#011validation-error:0.1459
# [04:30:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [129]#011train-error:0.092933#011validation-error:0.1457
# [04:30:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [130]#011train-error:0.092467#011validation-error:0.1462
# [04:30:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [131]#011train-error:0.092333#011validation-error:0.1459
# [04:30:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [132]#011train-error:0.092467#011validation-error:0.1459
# [04:30:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [133]#011train-error:0.092067#011validation-error:0.1462
# [04:30:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [134]#011train-error:0.092133#011validation-error:0.1456
# [04:30:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [135]#011train-error:0.0914#011validation-error:0.1453
# [04:30:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [136]#011train-error:0.091067#011validation-error:0.146
# [04:30:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [137]#011train-error:0.091067#011validation-error:0.1456
# [04:30:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [138]#011train-error:0.0906#011validation-error:0.1455
# [04:30:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [139]#011train-error:0.091067#011validation-error:0.1449
# [04:30:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [140]#011train-error:0.091267#011validation-error:0.1454
# [04:30:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [141]#011train-error:0.0906#011validation-error:0.1459
# [04:30:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [142]#011train-error:0.090133#011validation-error:0.1456
# [04:30:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [143]#011train-error:0.090133#011validation-error:0.145
# [04:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=5
# [144]#011train-error:0.090333#011validation-error:0.1457
# [04:30:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [145]#011train-error:0.089667#011validation-error:0.1452
# [04:30:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [146]#011train-error:0.0894#011validation-error:0.1442
# [04:30:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [147]#011train-error:0.089267#011validation-error:0.1444
# [04:30:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [148]#011train-error:0.088933#011validation-error:0.1447
# [04:30:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [149]#011train-error:0.0884#011validation-error:0.1447
# [04:30:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [150]#011train-error:0.088#011validation-error:0.1444
# [04:30:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [151]#011train-error:0.088267#011validation-error:0.1435
# [04:30:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [152]#011train-error:0.0882#011validation-error:0.1435
# [04:30:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [153]#011train-error:0.087867#011validation-error:0.1436
# [04:30:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [154]#011train-error:0.0876#011validation-error:0.1439
# [04:30:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=5
# [155]#011train-error:0.087867#011validation-error:0.1429
# [04:30:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [156]#011train-error:0.087867#011validation-error:0.1431
# [04:30:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [157]#011train-error:0.0876#011validation-error:0.1431
# [04:30:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [158]#011train-error:0.087467#011validation-error:0.1429
# [04:31:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [159]#011train-error:0.086933#011validation-error:0.1429
# [04:31:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [160]#011train-error:0.086667#011validation-error:0.1433
# [04:31:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [161]#011train-error:0.086467#011validation-error:0.1426
# [04:31:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [162]#011train-error:0.086333#011validation-error:0.1422
# [04:31:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [163]#011train-error:0.085733#011validation-error:0.1418
# [04:31:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [164]#011train-error:0.086267#011validation-error:0.1412
# [04:31:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [165]#011train-error:0.086067#011validation-error:0.1407
# [04:31:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [166]#011train-error:0.085133#011validation-error:0.1408
# [04:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [167]#011train-error:0.0852#011validation-error:0.1407
# [04:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [168]#011train-error:0.084933#011validation-error:0.1409
# [04:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [169]#011train-error:0.084733#011validation-error:0.1406
# [04:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [170]#011train-error:0.083933#011validation-error:0.1398
# [04:31:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [171]#011train-error:0.083867#011validation-error:0.1395
# [04:31:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [172]#011train-error:0.0836#011validation-error:0.1394
# [04:31:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [173]#011train-error:0.083467#011validation-error:0.1392
# [04:31:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [174]#011train-error:0.0828#011validation-error:0.1391
# [04:31:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [175]#011train-error:0.082867#011validation-error:0.1389
# [04:31:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [176]#011train-error:0.082467#011validation-error:0.1385
# [04:31:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [177]#011train-error:0.0826#011validation-error:0.1388
# [04:31:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [178]#011train-error:0.082467#011validation-error:0.1387
# [04:31:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [179]#011train-error:0.082#011validation-error:0.1383
# [04:31:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [180]#011train-error:0.082533#011validation-error:0.1382
# [04:31:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [181]#011train-error:0.0824#011validation-error:0.1387
# [04:31:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [182]#011train-error:0.081667#011validation-error:0.1389
# [04:31:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [183]#011train-error:0.081267#011validation-error:0.1384
# [04:31:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [184]#011train-error:0.081467#011validation-error:0.1388
# [04:31:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [185]#011train-error:0.0812#011validation-error:0.1387
# [04:31:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [186]#011train-error:0.0812#011validation-error:0.1385
# [04:31:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [187]#011train-error:0.080733#011validation-error:0.1389
# [04:31:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [188]#011train-error:0.080533#011validation-error:0.1381
# [04:31:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [189]#011train-error:0.080733#011validation-error:0.138
# [04:31:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [190]#011train-error:0.080133#011validation-error:0.1386
# [04:31:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [191]#011train-error:0.08#011validation-error:0.1381
# [04:31:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [192]#011train-error:0.079933#011validation-error:0.1388
# [04:31:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [193]#011train-error:0.0798#011validation-error:0.139
# [04:31:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [194]#011train-error:0.079467#011validation-error:0.1384
# [04:31:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [195]#011train-error:0.079333#011validation-error:0.1378
# [04:31:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [196]#011train-error:0.079133#011validation-error:0.1372
# [04:31:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [197]#011train-error:0.079333#011validation-error:0.1369
# [04:31:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [198]#011train-error:0.0798#011validation-error:0.1364
# [04:31:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [199]#011train-error:0.079333#011validation-error:0.1362
# [04:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [200]#011train-error:0.0788#011validation-error:0.1362
# [04:31:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [201]#011train-error:0.0784#011validation-error:0.1363
# [04:31:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [202]#011train-error:0.078267#011validation-error:0.1367
# [04:31:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [203]#011train-error:0.0782#011validation-error:0.1367
# [04:31:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [204]#011train-error:0.077933#011validation-error:0.137
# [04:31:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [205]#011train-error:0.077933#011validation-error:0.1369
# [04:32:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [206]#011train-error:0.077067#011validation-error:0.1358
# [04:32:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [207]#011train-error:0.076733#011validation-error:0.1362
# [04:32:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [208]#011train-error:0.0766#011validation-error:0.1364
# [04:32:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [209]#011train-error:0.076667#011validation-error:0.1356
# [04:32:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [210]#011train-error:0.076333#011validation-error:0.1353
# [04:32:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [211]#011train-error:0.0756#011validation-error:0.1361
# [04:32:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [212]#011train-error:0.0762#011validation-error:0.1354
# [04:32:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=5
# [213]#011train-error:0.075267#011validation-error:0.1349
# [04:32:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [214]#011train-error:0.0748#011validation-error:0.1353
# [04:32:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [215]#011train-error:0.075067#011validation-error:0.1348
# [04:32:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [216]#011train-error:0.074933#011validation-error:0.135
# [04:32:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [217]#011train-error:0.075#011validation-error:0.1352
# [04:32:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [218]#011train-error:0.074867#011validation-error:0.1356
# [04:32:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [219]#011train-error:0.0754#011validation-error:0.136
# [04:32:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [220]#011train-error:0.0748#011validation-error:0.1351
# [04:32:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [221]#011train-error:0.074867#011validation-error:0.1345
# [04:32:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [222]#011train-error:0.0748#011validation-error:0.1349
# [04:32:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [223]#011train-error:0.0746#011validation-error:0.1346
# [04:32:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [224]#011train-error:0.0744#011validation-error:0.1346
# [04:32:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [225]#011train-error:0.074467#011validation-error:0.1347
# [04:32:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [226]#011train-error:0.0744#011validation-error:0.1346
# [04:32:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [227]#011train-error:0.073733#011validation-error:0.1339
# [04:32:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [228]#011train-error:0.0736#011validation-error:0.1342
# [04:32:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=5
# [229]#011train-error:0.0732#011validation-error:0.1347
# [04:32:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [230]#011train-error:0.072933#011validation-error:0.1345
# [04:32:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [231]#011train-error:0.072467#011validation-error:0.1338
# [04:32:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [232]#011train-error:0.073#011validation-error:0.1339
# [04:32:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [233]#011train-error:0.073#011validation-error:0.1337
# [04:32:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [234]#011train-error:0.072733#011validation-error:0.133
# [04:32:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [235]#011train-error:0.072267#011validation-error:0.1331
# [04:32:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [236]#011train-error:0.0718#011validation-error:0.1325
# [04:32:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [237]#011train-error:0.071667#011validation-error:0.1319
# [04:32:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 22 pruned nodes, max_depth=5
# [238]#011train-error:0.072#011validation-error:0.1319
# [04:32:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [239]#011train-error:0.071667#011validation-error:0.1316
# [04:32:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [240]#011train-error:0.0712#011validation-error:0.1316
# [04:32:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [241]#011train-error:0.071267#011validation-error:0.1319
# [04:32:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [242]#011train-error:0.071067#011validation-error:0.1317
# [04:32:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [243]#011train-error:0.070467#011validation-error:0.1316
# [04:32:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=5
# [244]#011train-error:0.0706#011validation-error:0.1312
# [04:32:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [245]#011train-error:0.070267#011validation-error:0.1315
# [04:32:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [246]#011train-error:0.070733#011validation-error:0.132
# [04:32:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [247]#011train-error:0.0706#011validation-error:0.1321
# [04:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [248]#011train-error:0.0702#011validation-error:0.1317
# [04:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [249]#011train-error:0.070733#011validation-error:0.1329
# [04:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [250]#011train-error:0.070667#011validation-error:0.1327
# [04:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [251]#011train-error:0.0702#011validation-error:0.133
#
# 2020-04-14 04:33:09 Uploading - Uploading generated training model
# 2020-04-14 04:33:09 Completed - Training job completed
# [04:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [252]#011train-error:0.070067#011validation-error:0.1325
# [04:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [253]#011train-error:0.069667#011validation-error:0.1326
# [04:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [254]#011train-error:0.069267#011validation-error:0.1333
# Stopping. Best iteration:
# [244]#011train-error:0.0706#011validation-error:0.1312
#
# Training seconds: 390
# Billable seconds: 390

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# WARNING:sagemaker:Using already existing model: xgboost-2020-04-14-04-24-34-315

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ....................Arguments: serve
# [2020-04-14 04:37:41 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-04-14 04:37:41 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-04-14 04:37:41 +0000] [1] [INFO] Using worker: gevent
# [2020-04-14 04:37:41 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-04-14 04:37:41 +0000] [41] [INFO] Booting worker with pid: 41
# [2020-04-14 04:37:41 +0000] [42] [INFO] Booting worker with pid: 42
# [2020-04-14 04:37:42 +0000] [43] [INFO] Booting worker with pid: 43
# [2020-04-14:04:37:42:INFO] Model loaded successfully for worker : 41
# [2020-04-14:04:37:42:INFO] Model loaded successfully for worker : 40
# [2020-04-14:04:37:42:INFO] Model loaded successfully for worker : 42
# [2020-04-14:04:37:42:INFO] Model loaded successfully for worker : 43
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# 2020-04-14T04:38:04.429:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:07:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:07:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:09:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:09:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:09:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:09:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:09:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:09:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:09:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:09:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:10:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:10:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:10:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:10:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:10:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:10:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:10:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:10:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:12:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:12:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:14:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:14:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:14:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:14:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:14:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:14:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:15:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:15:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:14:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:14:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:15:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:15:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:15:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:15:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:15:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:15:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:17:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:17:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:19:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:19:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:19:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:19:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:20:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:19:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:19:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:19:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:19:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:20:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:20:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:20:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:20:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:20:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:20:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:20:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:22:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:22:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:25:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:24:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:24:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:25:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:25:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:25:INFO] Determined delimiter of CSV input is ','
#
# [2020-04-14:04:38:26:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:26:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:27:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:27:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','
# [2020-04-14:04:38:29:INFO] Sniff delimiter as ','
# [2020-04-14:04:38:29:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-2-622502871738/xgboost-2020-04-14-04-34-33-417/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86832

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
